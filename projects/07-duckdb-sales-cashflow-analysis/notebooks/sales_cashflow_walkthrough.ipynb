# %% [markdown]
# # DuckDB Sales Cashflow Analysis
#
# This notebook provides a simple walkthrough for the synthetic sales and cashflow analysis project.

# %%
from pathlib import Path
import duckdb

project_root = Path('..').resolve()
db_path = project_root / 'sales_cashflow.duckdb'
con = duckdb.connect(str(db_path))
print(con.execute('SELECT COUNT(*) FROM sales_orders').fetchone())
con.close()
