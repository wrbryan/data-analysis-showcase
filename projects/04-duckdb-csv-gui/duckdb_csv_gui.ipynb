# %% [markdown]
# # DuckDB CSV Relationship Manager
#
# This notebook loads CSV files into DuckDB, infers likely relationships, and lets you approve them through a GUI.

# %%
from pathlib import Path

from duckdb_csv_gui import build_gui

project_dir = Path.cwd()
gui = build_gui(project_dir)
gui
